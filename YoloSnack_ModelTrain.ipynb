# %% [markdown]
# <a href="https://colab.research.google.com/github/gusdnhh/YoloSnackDetect/blob/main/YoloSnack_ModelTrain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ultralytics 설치
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 882.2/882.2 kB 14.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import yaml

# data.yaml 파일 내용
data_yaml_content = {
    'train': '/content/drive/MyDrive/yolov11/snack_project/yolo_snack_dataset/trains',       # train 이미지 경로
    'val': '/content/drive/MyDrive/yolov11/snack_project/yolo_snack_dataset/valids',         # val 이미지 경로
    'nc': 5,                                   # 클래스 개수
    'names': ['jeli', 'pota', 'jt', 'br', 'mon']  # 클래스 이름 목록
}

# data.yaml 파일 생성
with open('data.yaml', 'w') as file:
    yaml.dump(data_yaml_content, file)

print("data.yaml 파일이 생성되었습니다.")
# Out:
# data.yaml 파일이 생성되었습니다.

# %%
! cat /content/data.yaml
# Out:
# names:
# - jeli
# - pota
# - jt
# - br
# - mon
# nc: 5
# train: /content/drive/MyDrive/yolov11/snack_project/yolo_snack_dataset/trains
# val: /content/drive/MyDrive/yolov11/snack_project/yolo_snack_dataset/valids

# %%
# !pwd
# Out:
# /content

# %%
# CLI 기반으로 학습
# !yolo train model=yolo11n.pt data=/content/data.yaml epochs=500 batch=32
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 5.35M/5.35M [00:00<00:00, 19.6MB/s]
# Ultralytics 8.3.9 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import os
import shutil

# Google Drive 경로 설정
destination_dir = '/content/drive/MyDrive/yolov11/snack_project/weights/'

# 폴더가 없으면 생성
os.makedirs(destination_dir, exist_ok=True)

# 파일 복사
shutil.copy('/content/runs/detect/train/weights/best.pt', os.path.join(destination_dir, 'best500_5(earlystop).pt'))

print("파일이 Google Drive에 성공적으로 복사되었습니다.")
# Out:
# 파일이 Google Drive에 성공적으로 복사되었습니다.
